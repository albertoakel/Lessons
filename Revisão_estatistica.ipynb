# %% [markdown]
# <a href="https://colab.research.google.com/github/albertoakel/Atividades_EBAC/blob/master/notebook/Revis%C3%A3o_estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Revisão estatistica
#
# ### *Para pensar*
# ---
# Suponha que uma população de bactérias de uma espécie em um determinado ecosistema vivam, em geral, entre 4 e 6 horas. Qual a chance de uma bactéria viver exatamente 5 horas? Bem, surpreendentemente, a resposta é 0%! Pode parecer estranho, mas é a pura verdade. Talvez você tenha ficado chocado com isso, mas, na ciência, a forma como fazemos a pergunta é super importante para o resultado.
#
# É claro que, na prática, algumas bactérias podem viver 5 horas, mas, probabilisticamente falando, a pergunta foi mal formulada e, por isso, não dá para quantificar. Afinal, a probabilidade de algo acontecer exatamente em um ponto específico (como 5 horas) é zero. Mas calma, não precisa ficar triste! Vamos reformular a pergunta para algo que faça sentido e seja quantificável.
#
# Que tal pensar assim: qual a probabilidade de uma bactéria morrer entre 5 horas e 5.01 horas? Agora sim! Temos um intervalo mensurável. Vamos supor que a resposta seja 0,02 (ou 2%). Se a gente diminuir esse intervalo para 5h a 5.001h, ou seja, 10 vezes menor, é de se esperar que a probabilidade também caia na mesma proporção, algo como 0,002 (0,2%). E se a gente apertar ainda mais, para 5h a 5.001h a probabilidade seria algo em torno de 0,0002 (0,02%).
#
# Percebeu? Quanto menor o intervalo, menor a probabilidade. É como se a natureza dissesse: "Quanto mais preciso você quer, menos chances eu te dou! \
# Em resumo temos o seguinte: \
# * Q1. 5-5.01  : P=0.02   (2%)
# * Q2. 5-5.001 : P=0.002  (0.2%)
# * Q3. 5-5.0001: P=0.0002 (0.02%)
#
# Observamos que, no intervalo de 0.01h (ou 36 segundos), a chance de uma bactéria morrer é de 2%. Agora, vamos fazer o inverso: aumentar o intervalo. Se 0,01h corresponde a 2%, então um intervalo 10 vezes maior (0,1h ou 6 minutos) teria uma probabilidade 10 vezes maior, ou seja, 20%. Se aumentarmos ainda mais, para 1h, a probabilidade seria 100 vezes maior que o original, chegando a 200%. Mas espera aí... 200%? Como assim? Isso não faz sentido, né? Afinal, a probabilidade não pode passar de 100%! Fique com essa questão guardada, mas tarde explicaremos melhor. É bom se acostumar com perguntas não respondidas 🥸
#
# Nesses exemplos, a razão entre a probabilidade de morrer durante um intervalo e a duração do intervalo ($\frac{P(\Delta_{t})}{\Delta t} $) é aproximadamente constante, igual a 2 por hora
# (ou $2.hora^{-1}$). Esta quantidade é chamada de **densidade de probabilidade ou PDF(não é o arquivo! )**. \
# Se quisermos saber a probabilidade de uma bactéria morrer em 0.01h (36 segundos), basta multiplicar a densidade de probabilidade pelo intervalo: 2*0.01=0.02 (2%)
#
# **Assim, em resposta à pergunta qual é a probabilidade de que a bactéria morra em 5 horas?** Usando o que já temos, a probabilidade de morrer em um intervalo de tempo $\Delta t$
# $$P=2\Delta t = 2 \times 0=zero!$$
# Então a resposta é zero mesmo 😊
#
# Vamos imaginar um valor próximo da hora exata,apertar nossa questão. 5h +1ns, ou seja nosso $\Delta t=10^{-9}s$. Lembrando que estamos trabalhando com hora. Assim:
#  $$1s=2.7\times 10^{-4}h$$.
# Desta forma, **A probabilidade é de viver nesse curto espaço de tempo é: **
# $$P=2\Delta t = 2 \times 2.7\times 10^{-4}h=5.4 \times 10^{-13}$$ \
#
# Pensamos em um grupo de bactérias e no tempo de vida delas. Se fôssemos agrupá-las pelo tempo de vida, teríamos uma curva do tempo de vida pela quantidade de bactérias. Essa curva, também chamada de função ou distribuição, é uma representação matemática dessa natureza. Aqui, iremos tratar de uma distribuição muito específica chamada normal, também conhecida como função gaussiana.
#
# ---
# A equação da distribuição normal é definida por:
#
# $$f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{1}{2} \left( \frac{x - \mu}{\sigma} \right)^2}$$
#
# Onde:
#
# $μ$  média da distribuição; \
# $\sigma$ é o desvio padrão; \
# $x$ é a variável aleatória;
#
# Algumas caracteristicas;
# Média $=$ Mediana($M_{d}$) ( ou quase isso para dados reais)

# %%
import numpy as np
import math as ma
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy import integrate
from IPython.display import display, Math

x = np.linspace(-4, 4, 1000)
mu=0
sig=1
k=1/(sig*np.sqrt(2*ma.pi))
y=k*np.exp(-0.5*((x-mu)/sig)**2)
plt.plot(x,y,label='gaussina')
y=[0,0]
x1=[mu+sig,mu-sig]
x2=[mu+2*sig,mu-2*sig]
x3=[mu+3*sig,mu-3*sig]

x05=[0 +0.5]
plt.scatter(x1,y,color='red')
plt.scatter(x2,y,color='purple')
plt.scatter(x3,y,color='green')


xo1=np.linspace(x1[0],4,1000)
k=1/(sig*np.sqrt(2*ma.pi))
y1=k*np.exp(-0.5*((xo1-mu)/sig)**2)

xo2=np.linspace(x2[0],4,1000)
k=1/(sig*np.sqrt(2*ma.pi))
y2=k*np.exp(-0.5*((xo2-mu)/sig)**2)

xo3=np.linspace(x3[0],4,1000)
k=1/(sig*np.sqrt(2*ma.pi))
y3=k*np.exp(-0.5*((xo3-mu)/sig)**2)

plt.fill_between(xo1,y1+0.003,alpha=1,color='red',label='$\\mu+ 1\\sigma$')
plt.fill_between(xo2,y2+0.002,alpha=1,color='purple',label='$\\mu+ 2\\sigma$')
plt.fill_between(xo3,y3+0.001,alpha=1,color='green',label='$\\mu+ 3\\sigma$')

plt.grid(True)
plt.legend()

# %% [markdown]
# ### Calculando as probabilidades
# Em teoria das probabilidades , a função densidade de probabilidade (FDP) é uma função que descreve a verossimilhança de uma variável aleatória tomar um valor dado. A probabilidade da variável aleatória cair em uma faixa particular é dada pela integral da densidade dessa variável sobre tal faixa - isto é, é dada pela área abaixo da função densidade mas acima do eixo horizontal e entre o menor e o maior valor dessa faixa. Assim.
#
# $$ P[a \leqslant X \leqslant b] =\int_{a}^{b} f(x) dx  $$
# Se nossa função de densidade de probalidade é conhecidada e é a gaussina. Então pode podemos definir a probabilidade entre $x_1$ e $x_2$
# $$P[x1:x2]=\int_{x_1}^{x_2} \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{1}{2} \left( \frac{x - \mu}{\sigma} \right)^2} dx$$

# %%
p1=integrate.simpson(y1,x=xo1);
p2=integrate.simpson(y2,x=xo2);
p3=integrate.simpson(y3,x=xo3);
#multiplicar o valor por 2
print(f"P1(mu+-1sig) = {2*p1:.3f}")
print(f"P2(mu+-2sig) = {2*p2 * 2:.3f}")
print(f"P3(mu+-3sig) = {2*p3 * 2:.3f}")

####

x = np.linspace(-10, 10, 1000)
mu=0
sig=1
k=1/(sig*np.sqrt(2*ma.pi))
y=k*np.exp(-0.5*((x-mu)/sig)**2)
plt.plot(x,y)


sig=1

mu=0
xo=np.linspace(-10,-0.5,1000000)
k=1/(sig*np.sqrt(2*ma.pi))
y5=k*np.exp(-0.5*((xo-mu)/sig)**2)
p5=integrate.simpson(y5,x=xo);
print(f"P5 = {p5:.3f}")
#plt.plot(xo,y5)
plt.fill_between(xo,y5,alpha=0.2)
# Out:
# P1(mu+-1sig) = 0.317
# P2(mu+-2sig) = 0.091
# P3(mu+-3sig) = 0.005
# P5 = 0.309

# %%
from scipy.stats import norm

media_amostra = 12.6
mu0 = 12
sigma = 2
n = 10
# Estatística Z
z = (media_amostra - mu0) / (sigma / (n**0.5))

# Valor-p (bicaudal)
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Estatística Z: {z:.2f}")
print(f"Valor-p: {p_value:.4f}")
# Out:
# Estatística Z: 0.95
# Valor-p: 0.3428

# %%
data = np.random.normal(2,3, size=1000)
plt.hist(data, bins=50)
plt.show()

# %%
mu=0
sig=2
population = np.random.normal(0, sig, size=10000);
sample = np.random.choice(population, size=100, replace=False)

print(f"Média (População): {np.mean(population):.3f}, \
Desvio Padrão (População): {np.std(population):.3f}, \
Mediana (População): {np.median(population):.3f}")

print(f"Média (Amostraa): {np.mean(sample):.3f},\
 Desvio Padrão (Amostra): {np.std(sample):.3f}, \
 Mediana (Amostra): {np.median(sample):.3f}")
#plt.plot(population)
plt.subplot(2,1,1)
plt.plot(population)
plt.subplot(2,1,2)

yo, xo, _ =plt.hist(population, bins=50);
#y= plt.hist(population)
x = np.linspace(-10, 10, 10000)

k=1/(sig*np.sqrt(2*ma.pi))
A=max(yo)
y=k*np.exp(-0.5*((x-mu)/sig)**2)
ynorm=y/max(y)*A


plt.plot(x,ynorm);
# Out:
# Média (População): 0.034, Desvio Padrão (População): 2.020, Mediana (População): 0.033
# Média (Amostraa): 0.029, Desvio Padrão (Amostra): 2.021,  Mediana (Amostra): -0.154

# %% [markdown]
# ### **Teste de Hipótese**
# ### 1. Problema
# Suponha que você tenha uma amostra de notas de alunos em uma prova e queira testar se a média das notas é significativamente diferente de 7.0 (um valor de referência).
#
# #### 2. Hipótese
# *   hipótese nula ($H_{o}$): A média das notas é **igual** a 7.0 \
# $H_{o}: \mu=7.0$
# *   hipótese alternativa ($H_{1}$): A média das notas é **diferente** de 7.0 \
# $H_{o}: \mu\neq7.0$
#
# #### 3. Dados
# supondo a seguinte coleção de notas:\
# notas=[6.5, 7.2, 6.8, 7.5, 6.9, 7.1, 6.7, 7.4, 6.6, 7.3]
#
# #### 4. Método
# Como n, total de elementos da coleção é baixo, podemos usar o método t-student. Assim definimos a seguinte equação para t:
#
# $$t=\frac{( \bar{x}-\mu_o)\sqrt{\nu}}{s}$$
#
# onde:\
# $\bar{x}$ é a média da amostra \
# $\mu_o$ é o valor de referência \
# $s$ é o desvio da amostra \
# $\nu$ graus de liberdada, $\nu=n-1$
# ###
# **passos ** \
# calculando a média, desvio podemos calcular o valor de t, assim: \
# $\bar{x}$ = 7.0 \
# $s$ = 0.316 \
# Finalmente: $t = 0$
#
# **Determinação do valor-p** \
# O valor-p mede a probabilidade de obter os resultados observados, assumindo que a hipótese nula é verdadeira. Ele varia de 0 a 1.Em um teste de hipóteses, você formula uma hipótese nula que representa uma afirmação a ser testada – onde os grupos comparados não tem diferença entre si –, e uma hipótese alternativa – que é a afirmação oposta. Indica a probabilidade de obter os resultados observados, assumindo que a hipótese nula seja verdadeira.
#
# * Se o valor-p for menor que o nível de significância (geralmente $\alpha$ =0,05), rejeitamos $H_o$
# * Caso contrário, não rejeitamos $H_o$
#
# O valor-P depende do teste de hipótese proposto.
#
# 1.   Teste bicaudal: $H_1:\mu \neq \mu_{o}$ \
#       $$valor_p=2P(T>|t|)$$
# 2.   Teste unicaudal à direita $H_1:\mu > \mu_{o}$
# $$valor_p=P(T>t)$$
# 3.   Teste unicaudal à direita $H_1:\mu < \mu_{o}$
# $$valor_p=2P(T<t)$$

# %%
# Valor de referência
valor_referencia = 7.0
notas = [6.5, 7.2, 6.8, 7.5, 6.9, 7.1, 6.7, 7.4, 6.6, 7.3]
# Realizar o teste t para uma amostra
resultado = stats.ttest_1samp(notas, valor_referencia)

# Exibir o resultado
print("Estatística t:", resultado.statistic)
print("Valor-p:", resultado.pvalue)
resultado
# Out:
# Estatística t: 0.0
# Valor-p: 1.0
# TtestResult(statistic=0.0, pvalue=1.0, df=9)

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.linspace(-3,3,100000)
y=norm.pdf(x,0,1)
print(np.std(y))
#plt.plot(x,y,'r-');

c=np.cumsum(y)
c=c/max(c)
id=np.where(x>=0.95)
p=id[0][0]
#print('cumsum   0.95:',c[p])
#print('norm.cdf 0.95:',norm.cdf(0.95))

plt.plot(x,norm.cdf(x))

plt.plot(x,c,'--r')
plt.grid()


x = np.linspace(-3, 3, 1000)
mu=0
sig=1
k=1/(sig*np.sqrt(2*ma.pi))
Y=k*np.exp(-0.5*((x-mu)/sig)**2)
C=np.cumsum(Y)
C=C/max(C)
plt.plot(x,C,'+g',alpha=0.1)

id=np.where(x>=0.95)
P=id[0][0]
print('cumsum   0.95:',c[p])
print('norm.cdf 0.95:',norm.cdf(0.95))
print('CUMSUM   0.95:',C[P])
# Out:
# 0.13923661990699976
# cumsum   0.95: 0.8298468810839714
# norm.cdf 0.95: 0.8289438736915182
# CUMSUM   0.95: 0.8310852007381296

# %%
import numpy as np

# Função PDF da distribuição normal padrão
def pdf_normal(z):
    return (1 / np.sqrt(2 * np.pi)) * np.exp(-z**2 / 2)

# Função para calcular a integral usando a regra de Simpson
def simpson(f, a, b, n):
    if n % 2 != 0:
        raise ValueError("O número de subintervalos (n) deve ser par.")

    h = (b - a) / n
    x = np.linspace(a, b, n+1)
    y = f(x)

    integral = (h / 3) * (y[0] + 4 * np.sum(y[1:-1:2]) + 2 * np.sum(y[2:-2:2]) + y[-1])
    return integral

# Função para calcular a CDF da distribuição normal padrão
def cdf_normal(z, n=1000):
    if z < 0:
        return 0.5 - simpson(pdf_normal, z, 0, n)
    else:
        return 0.5 + simpson(pdf_normal, 0, z, n)

# Exemplo de uso
z = 1-0.95  # Valor de Z para calcular a CDF
cdf_z = cdf_normal(z)
print(f"P(Z <= {z}) = {cdf_z:.4f}")
# Out:
# P(Z <= 0.050000000000000044) = 0.5199
